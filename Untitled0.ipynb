# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardo314111/test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Class 2 Data types.
# Eduardo Romero Ricaud

# %%
x = 2

# %%
type(x)
# Out:
# int

# %%
x1 = 3.0
type(x1)
# Out:
# float

# %%
x2 = 'hi'
type(x2)
# Out:
# str

# %%
import math

# %%
x3 = 'math.pi'

# %%
x4 = math.pi

# %%
type(x4)
# Out:
# float

# %%
x5 = None
type(x5)
# Out:
# NoneType

# %%
import pandas as pd
x6 = pd.NaT
x6
# Out:
# NaT

# %%
type(x6)
# Out:
# pandas._libs.tslibs.nattype.NaTType

# %%
import numpy as np
x7 = np.nan
x7
# Out:
# nan

# %%
type(x7)
# Out:
# float

# %%
x8 = [2,3,5,8, None, 'hi', 2/3, pd.NaT, -3]
x8
# Out:
# [2, 3, 5, 8, None, 'hi', 0.6666666666666666, NaT, -3]

# %%
type(x8)
# Out:
# list

# %%
x9 = (2,3,5,8, None, 'hi', 2/3, pd.NaT, -3)
x9
# Out:
# (2, 3, 5, 8, None, 'hi', 0.6666666666666666, NaT, -3)

# %%
type(x9)
# Out:
# tuple

# %%
x8
# Out:
# [2, 3, 5, 8, None, 'hi', 0.6666666666666666, NaT, -3]

# %%
x8[0]
# Out:
# 2

# %%
x8[1] = 300
x8
# Out:
# [2, 300, 5, 8, None, 'hi', 0.6666666666666666, NaT, -3]

# %%
x9[1]
# Out:
# 3

# %%
a = {
    1:['First Name', 'Gustavo'],
    2: 'Last Name',
    'Age': 33
}

# %%
type(a)
# Out:
# dict

# %%
a[1]
# Out:
# ['First Name', 'Gustavo']

# %% [markdown]
# ## 1.2 Data Wrangling

# %%
path = 'https://raw.githubusercontent.com/tec03/Datasets/refs/heads/main/datasets/Cartwheeldata.csv'

# %%
import pandas as pd
df = pd.read_csv(path)
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
df.shape
# Out:
# (25, 12)

# %%
type(x)
# Out:
# int

# %%
df.shape[1]
# Out:
# 12

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
y1 = df.columns

# %%
type(y1)
# Out:
# pandas.core.indexes.base.Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
y3 = df.index
y3
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
type(y3)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %% [markdown]
# ##1.2 Table Slicing
#
# ####1. Just show average of 'Age'

# %%
age_data1 = df.Age
age_data1
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
type(age_data1)
# Out:
# pandas.core.series.Series

# %%
age_data1.mean()
# Out:
# np.float64(28.24)

# %%
age2 = df['Age']
age2
# Out:
# 0     56
# 1     26
# 2     33
# 3     39
# 4     27
# 5     24
# 6     28
# 7     22
# 8     29
# 9     33
# 10    30
# 11    28
# 12    25
# 13    23
# 14    31
# 15    26
# 16    26
# 17    27
# 18    23
# 19    24
# 20    23
# 21    29
# 22    25
# 23    26
# 24    23
# Name: Age, dtype: int64

# %%
type(age2)
# Out:
# pandas.core.series.Series

# %%
age3 = df[['Age']]
age3
# Out:
#     Age
# 0    56
# 1    26
# 2    33
# 3    39
# 4    27
# 5    24
# 6    28
# 7    22
# 8    29
# 9    33
# 10   30
# 11   28
# 12   25
# 13   23
# 14   31
# 15   26
# 16   26
# 17   27
# 18   23
# 19   24
# 20   23
# 21   29
# 22   25
# 23   26
# 24   23

# %%
type(age3)
# Out:
# pandas.core.frame.DataFrame

# %%
favs = ['Age','Gender']
df[favs]
# Out:
#     Age Gender
# 0    56      F
# 1    26      F
# 2    33      F
# 3    39      F
# 4    27      M
# 5    24      M
# 6    28      M
# 7    22      F
# 8    29      M
# 9    33      F
# 10   30      M
# 11   28      F
# 12   25      F
# 13   23      F
# 14   31      M
# 15   26      M
# 16   26      F
# 17   27      M
# 18   23      M
# 19   24      F
# 20   23      M
# 21   29      M
# 22   25      M
# 23   26      M
# 24   23      F

# %% [markdown]
# ### loc and iloc:

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.loc[ : , 'Age': 'Gender' ]
# Out:
#     Age Gender
# 0    56      F
# 1    26      F
# 2    33      F
# 3    39      F
# 4    27      M
# 5    24      M
# 6    28      M
# 7    22      F
# 8    29      M
# 9    33      F
# 10   30      M
# 11   28      F
# 12   25      F
# 13   23      F
# 14   31      M
# 15   26      M
# 16   26      F
# 17   27      M
# 18   23      M
# 19   24      F
# 20   23      M
# 21   29      M
# 22   25      M
# 23   26      M
# 24   23      F

# %%
df.iloc[:, 1:3]
# Out:
#     Age Gender
# 0    56      F
# 1    26      F
# 2    33      F
# 3    39      F
# 4    27      M
# 5    24      M
# 6    28      M
# 7    22      F
# 8    29      M
# 9    33      F
# 10   30      M
# 11   28      F
# 12   25      F
# 13   23      F
# 14   31      M
# 15   26      M
# 16   26      F
# 17   27      M
# 18   23      M
# 19   24      F
# 20   23      M
# 21   29      M
# 22   25      M
# 23   26      M
# 24   23      F

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %% [markdown]
# Prunt and the Calculated meand of : Age, Height, and wingspan.

# %%
df.loc[ : , ['Age','Height','Wingspan']]
# Out:
#     Age  Height  Wingspan
# 0    56   62.00      61.0
# 1    26   62.00      60.0
# 2    33   66.00      64.0
# 3    39   64.00      63.0
# 4    27   73.00      75.0
# 5    24   75.00      71.0
# 6    28   75.00      76.0
# 7    22   65.00      62.0
# 8    29   74.00      73.0
# 9    33   63.00      60.0
# 10   30   69.50      66.0
# 11   28   62.75      58.0
# 12   25   65.00      64.5
# 13   23   61.50      57.5
# 14   31   73.00      74.0
# 15   26   71.00      72.0
# 16   26   61.50      59.5
# 17   27   66.00      66.0
# 18   23   70.00      69.0
# 19   24   68.00      66.0
# 20   23   69.00      67.0
# 21   29   71.00      70.0
# 22   25   70.00      68.0
# 23   26   69.00      71.0
# 24   23   65.00      63.0

# %%
favs = ['Age', 'Height', 'Wingspan']
ndf=df[favs]
ndf.head(2)
# Out:
#    Age  Height  Wingspan
# 0   56    62.0      61.0
# 1   26    62.0      60.0

# %%
ndf.median
# Out:
# <bound method DataFrame.median of     Age  Height  Wingspan
# 0    56   62.00      61.0
# 1    26   62.00      60.0
# 2    33   66.00      64.0
# 3    39   64.00      63.0
# 4    27   73.00      75.0
# 5    24   75.00      71.0
# 6    28   75.00      76.0
# 7    22   65.00      62.0
# 8    29   74.00      73.0
# 9    33   63.00      60.0
# 10   30   69.50      66.0
# 11   28   62.75      58.0
# 12   25   65.00      64.5
# 13   23   61.50      57.5
# 14   31   73.00      74.0
# 15   26   71.00      72.0
# 16   26   61.50      59.5
# 17   27   66.00      66.0
# 18   23   70.00      69.0
# 19   24   68.00      66.0
# 20   23   69.00      67.0
# 21   29   71.00      70.0
# 22   25   70.00      68.0
# 23   26   69.00      71.0
# 24   23   65.00      63.0>

# %%
favs
# Out:
# ['Age', 'Height', 'Wingspan']

# %%
a1 = df.loc[ : ,favs]
a1.head(2)
# Out:
#    Age  Height  Wingspan
# 0   56    62.0      61.0
# 1   26    62.0      60.0

# %%
a1.median()
# Out:
# Age         26.0
# Height      68.0
# Wingspan    66.0
# dtype: float64

# %%
df.loc[5:11, ['Age', 'Height', 'Wingspan']].median()
# Out:
# Age         28.0
# Height      69.5
# Wingspan    66.0
# dtype: float64
